# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set_style('ticks')
plt.rcParams['font.size']=10
plt.rcParams['figure.figsize']=(7,4)
plt.rcParams['figure.facecolor']='white'

# %%
data=pd.read_csv('happiness.csv')
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
data.shape
# Out:
# (158, 12)

# %% [markdown]
# # Checking for Missing Data

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# No missing data found in the dataset

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Visualisation

# %%
data.hist(figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Country'}>,
#         <AxesSubplot:title={'center':'Region'}>,
#         <AxesSubplot:title={'center':'Happiness Rank'}>],
#        [<AxesSubplot:title={'center':'Happiness Score'}>,
#         <AxesSubplot:title={'center':'Standard Error'}>,
#         <AxesSubplot:title={'center':'Economy (GDP per Capita)'}>],
#        [<AxesSubplot:title={'center':'Family'}>,
#         <AxesSubplot:title={'center':'Health (Life Expectancy)'}>,
#         <AxesSubplot:title={'center':'Freedom'}>],
#        [<AxesSubplot:title={'center':'Trust (Government Corruption)'}>,
#         <AxesSubplot:title={'center':'Generosity'}>,
#         <AxesSubplot:title={'center':'Dystopia Residual'}>]], dtype=object)

# %%
sns.barplot(x=data['Country'].head(5), y = data['Economy (GDP per Capita)'],data=data)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Economy (GDP per Capita)'>

# %%
sns.barplot(x=data['Country'].head(5),y=data['Happiness Score'],data=data)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Happiness Score'>

# %%
data.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
#encoding data from categorical to numerical data
from sklearn.preprocessing import LabelEncoder
lbl = LabelEncoder()
data['Country'] = lbl.fit_transform(data['Country'])
data['Region'] = lbl.fit_transform(data['Region'])

# %%
data['Country']
# Out:
# 0      135
# 1       58
# 2       37
# 3      105
# 4       24
#       ...
# 153    118
# 154     13
# 155    136
# 156     21
# 157    141
# Name: Country, Length: 158, dtype: int64

# %%
data['Region']
# Out:
# 0      9
# 1      9
# 2      9
# 3      9
# 4      5
#       ..
# 153    8
# 154    8
# 155    4
# 156    8
# 157    8
# Name: Region, Length: 158, dtype: int64

# %%
data
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153      118       8             154            3.465         0.03464
# 154       13       8             155            3.340         0.03656
# 155      136       4             156            3.006         0.05015
# 156       21       8             157            2.905         0.08658
# 157      141       8             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# # Correlation of Data

# %%
data.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(data.corr(), annot = True, linewidths = 0.6,cmap ='winter_r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above heatmap of correlations there is a high correlation between Happines score vs Economy(GDP per Capita),Family,Health(Life Expectancy)and between Economy vs Health(Life Expectancy)

# %% [markdown]
# # Describing Dataset

# %%
data.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %%
plt.figure(figsize=(10,12))
sns.heatmap(round(data.describe()[1:].transpose(),2),linewidth = 2, annot = True, fmt = 'f',cmap='twilight_shifted_r')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variable Summary")
plt.show()

# %% [markdown]
# # Checking for Outliers

# %%
data['Happiness Score'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data['Economy (GDP per Capita)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data['Family'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data['Health (Life Expectancy)'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data['Freedom'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data['Generosity'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data['Trust (Government Corruption)'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Columns having outliers-["Standard Error", "Family", "Trust (Government Corruption)", "Generosity" and "Dystopia Residual"]
# Columns without outliers-s["Country", "Region", "Happiness Rank", "Happiness Score","Economy (GDP per Capita)","Health (Life Expectancy)" and "Freedom"]

# %% [markdown]
# # Checking for skewness

# %%
data.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# # Normal Distribution Curve

# %%
sns.distplot(data['Economy (GDP per Capita)'])
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(data['Standard Error'])
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %%
sns.distplot(data['Family'])
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(data['Trust (Government Corruption)'])
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(data['Generosity'])
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %% [markdown]
# # Data Cleaning

# %%
delete = pd.DataFrame([["-0.177254","Standard Error","No", "Alot"],["0.395199","Trust (Government Corruption)","No","Alot"]],columns = ["Correlation with Target","Column_Name","Normalised","Outliers"])
delete
# Out:
#   Correlation with Target                    Column_Name Normalised Outliers
# 0               -0.177254                 Standard Error         No     Alot
# 1                0.395199  Trust (Government Corruption)         No     Alot

# %%
df = data.drop(["Standard Error","Trust (Government Corruption)"],axis=1)
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  \
# 0        135       9               1            7.587
# 1         58       9               2            7.561
# 2         37       9               3            7.527
# 3        105       9               4            7.522
# 4         24       5               5            7.427
# ..       ...     ...             ...              ...
# 153      118       8             154            3.465
# 154       13       8             155            3.340
# 155      136       4             156            3.006
# 156       21       8             157            2.905
# 157      141       8             158            2.839
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(data))
z.shape
# Out:
# (158, 12)

# %%
threshold=3
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
new = data[(z<3).all(axis=1)]
print(data.shape)
print(new.shape)
# Out:
# (158, 12)
# (149, 12)

# %%
#Percentage data loss
Data_loss=((158-149)/158)*100
Data_loss
# Out:
# 5.69620253164557

# %%
x = new.iloc[:,[0,1,2,4,5,6,7,8,9]] # considering all features except the independent variable
x
# Out:
#      Country  Region  Happiness Rank  Standard Error  \
# 0        135       9               1         0.03411
# 1         58       9               2         0.04884
# 2         37       9               3         0.03328
# 3        105       9               4         0.03880
# 4         24       5               5         0.03553
# ..       ...     ...             ...             ...
# 150       66       8             151         0.05141
# 151       20       8             152         0.04324
# 152        0       7             153         0.03084
# 154       13       8             155         0.03656
# 156       21       8             157         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
x.shape
# Out:
# (149, 9)

# %%
y = new.iloc[:,-1]
y
# Out:
# 0      2.51738
# 1      2.70201
# 2      2.49204
# 3      2.46531
# 4      2.45176
#         ...
# 150    1.41723
# 151    1.46494
# 152    1.95210
# 154    1.63328
# 156    1.83302
# Name: Dystopia Residual, Length: 149, dtype: float64

# %% [markdown]
# # Transforming data to remove skewness

# %%
from sklearn.preprocessing import power_transform
x = power_transform(x,method = 'yeo-johnson')
x
# Out:
# array([[ 1.19015533,  1.23451354, -2.05151352, ...,  1.4696364 ,
#          1.75498234,  1.81762514],
#        [-0.30048669,  1.23451354, -1.99584442, ...,  1.5112916 ,
#          1.44218195,  0.32967608],
#        [-0.80205671,  1.23451354, -1.94524081, ...,  1.05346933,
#          1.6160368 ,  1.95339957],
#        ...,
#        [-2.10537769,  0.66673577,  1.53128908, ..., -1.35238817,
#         -1.26539516, -0.19284339],
#        [-1.50728158,  0.95527966,  1.56626337, ..., -1.30970913,
#          0.31812329, -0.4344978 ],
#        [-1.24683102,  0.95527966,  1.60111233, ..., -1.55066259,
#         -1.84989335, -0.14727363]])

# %%
#Standard Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[ 1.19015533,  1.23451354, -2.05151352, ...,  1.4696364 ,
#          1.75498234,  1.81762514],
#        [-0.30048669,  1.23451354, -1.99584442, ...,  1.5112916 ,
#          1.44218195,  0.32967608],
#        [-0.80205671,  1.23451354, -1.94524081, ...,  1.05346933,
#          1.6160368 ,  1.95339957],
#        ...,
#        [-2.10537769,  0.66673577,  1.53128908, ..., -1.35238817,
#         -1.26539516, -0.19284339],
#        [-1.50728158,  0.95527966,  1.56626337, ..., -1.30970913,
#          0.31812329, -0.4344978 ],
#        [-1.24683102,  0.95527966,  1.60111233, ..., -1.55066259,
#         -1.84989335, -0.14727363]])

# %% [markdown]
# # Checking relation of Feature with the Target coloumns

# %%
sns.scatterplot(x= 'Dystopia Residual',y = 'Happiness Score',data = data)
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Happiness Score'>

# %%
sns.regplot(x = 'Economy (GDP per Capita)', y = 'Happiness Score', data = data)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
sns.regplot(x = 'Health (Life Expectancy)', y = 'Happiness Score', data = data)
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Happiness Score'>

# %% [markdown]
# From the above plots it can be observed that
# 1)Economy and Happiness Score have a linear relation i.e. if Economy increases Happiness Score increases.
# 2)The Health(Life Expectancy) and Happiness Score is deeply co-related with one another.

# %% [markdown]
# From the above visualisation, the relation between Feature and Target model is linear. Thus, Linear regression Model can be used.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
lr_model = LinearRegression()

# %% [markdown]
# # Splitting the Dataset

# %%
max_score = 0
for i in range(0,1000):
    x_train,x_test,y_train,y_test = train_test_split(x,y,random_state = i, test_size=0.30)
    lr_model.fit(x_train,y_train)
    pred_test = lr_model.predict(x_test)
    r2_scr = r2_score(y_test,pred_test)
    if r2_scr > max_score:
        max_score = r2_scr
        final_r2_state = i
print("Max r2 score corresponding to", final_r2_state, "is", max_score)
# Out:
# Max r2 score corresponding to 477 is 0.9656800928976289

# %%
#using cross validation to check overfiting or underfitting
from sklearn.model_selection import cross_val_score
score=cross_val_score(LinearRegression(),x,y,cv=5,scoring='r2')
score
# Out:
# array([0.88267397, 0.91939711, 0.89096054, 0.8364087 , 0.8209815 ])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state = 279,test_size=.30)
lr_model.fit(x_train,y_train)
pred_test = lr_model.predict(x_test)
pred_test
print("RMSE :", np.sqrt(mean_squared_error(y_test,pred_test)))

print("r2_score :",r2_score(y_test,pred_test))
# Out:
# RMSE : 0.1390415463261583
# r2_score : 0.8784150519624536

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor

# %%
rf = RandomForestRegressor(n_estimators = 100 )
svr=SVR()
dtc = DecisionTreeRegressor()
ad=AdaBoostRegressor()

model = [rf,svr,dtc,ad]

for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    pred_test = m.predict(x_test)
    print("r2_score of",m, ":",r2_score(y_test,pred_test))
    print('mean_squared_error',mean_squared_error(y_test,pred_test))
    print('mean_absolute_error',mean_absolute_error(y_test,pred_test))
    print('\n')
# Out:
# r2_score of RandomForestRegressor() : 0.6834896095013472
# mean_squared_error 0.08353071439686971
# mean_absolute_error 0.23316085000000009
#
#
# r2_score of SVR() : 0.8304531003779022
# mean_squared_error 0.04474536721178659
# mean_absolute_error 0.15335419551498333
#
#
# r2_score of DecisionTreeRegressor() : 0.45514809475205176
# mean_squared_error 0.14379265342333333
# mean_absolute_error 0.2976843333333334
#
#
# r2_score of AdaBoostRegressor() : 0.5855806397054069
# mean_squared_error 0.10937001205794047
# mean_absolute_error 0.25922400183201744

# %% [markdown]
# # Saving the best model

# %%
import joblib

joblib.dump(lr_model,'lrmodel.obj')
# Out:
# ['lrmodel.obj']

# %%
lrloadmodel = joblib.load('lrmodel.obj')

# %% [markdown]
# # Comparing the Orignal and Predicted data

# %%
import numpy as np
a = np.array(y_test)
predicted = np.array(lrloadmodel.predict(x_test))
df_com = pd.DataFrame({"Original":a,"Predicted":predicted},index= range(len(a)))
df_com
# Out:
#     Original  Predicted
# 0    1.68135   1.651845
# 1    1.71956   1.585601
# 2    2.75414   2.662025
# 3    1.86040   1.818914
# 4    2.37119   2.393869
# 5    2.04384   1.946610
# 6    1.38079   1.589792
# 7    1.73799   1.898605
# 8    2.51009   2.156066
# 9    1.26462   1.155092
# 10   2.43872   2.534003
# 11   2.21978   2.249930
# 12   2.32407   2.295490
# 13   2.84848   2.735471
# 14   1.87634   1.863694
# 15   1.79293   1.712608
# 16   2.44191   2.262747
# 17   2.23270   2.360372
# 18   1.96961   2.002711
# 19   2.53942   2.540529
# 20   2.74255   2.855709
# 21   2.26425   2.448966
# 22   1.62215   1.680921
# 23   3.19131   2.964859
# 24   1.59888   1.477754
# 25   1.21305   1.194723
# 26   3.05137   2.813041
# 27   2.67585   2.761645
# 28   1.68435   1.537434
# 29   1.95812   1.957496
